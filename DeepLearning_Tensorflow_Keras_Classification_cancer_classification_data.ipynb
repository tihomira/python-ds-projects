# %% [markdown]
# # Keras TF 2.0 - Code Along Classification Project
#
# Let's explore a classification task with Keras API for TF 2.0
#
# ## The Data
#
# ### Breast cancer wisconsin (diagnostic) dataset
# --------------------------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 569
#
#     :Number of Attributes: 30 numeric, predictive attributes and the class
#
#     :Attribute Information:
#         - radius (mean of distances from center to points on the perimeter)
#         - texture (standard deviation of gray-scale values)
#         - perimeter
#         - area
#         - smoothness (local variation in radius lengths)
#         - compactness (perimeter^2 / area - 1.0)
#         - concavity (severity of concave portions of the contour)
#         - concave points (number of concave portions of the contour)
#         - symmetry
#         - fractal dimension ("coastline approximation" - 1)
#
#         The mean, standard error, and "worst" or largest (mean of the three
#         largest values) of these features were computed for each image,
#         resulting in 30 features.  For instance, field 3 is Mean Radius, field
#         13 is Radius SE, field 23 is Worst Radius.
#
#         - class:
#                 - WDBC-Malignant
#                 - WDBC-Benign
#
#     :Summary Statistics:
#
#     ===================================== ====== ======
#                                            Min    Max
#     ===================================== ====== ======
#     radius (mean):                        6.981  28.11
#     texture (mean):                       9.71   39.28
#     perimeter (mean):                     43.79  188.5
#     area (mean):                          143.5  2501.0
#     smoothness (mean):                    0.053  0.163
#     compactness (mean):                   0.019  0.345
#     concavity (mean):                     0.0    0.427
#     concave points (mean):                0.0    0.201
#     symmetry (mean):                      0.106  0.304
#     fractal dimension (mean):             0.05   0.097
#     radius (standard error):              0.112  2.873
#     texture (standard error):             0.36   4.885
#     perimeter (standard error):           0.757  21.98
#     area (standard error):                6.802  542.2
#     smoothness (standard error):          0.002  0.031
#     compactness (standard error):         0.002  0.135
#     concavity (standard error):           0.0    0.396
#     concave points (standard error):      0.0    0.053
#     symmetry (standard error):            0.008  0.079
#     fractal dimension (standard error):   0.001  0.03
#     radius (worst):                       7.93   36.04
#     texture (worst):                      12.02  49.54
#     perimeter (worst):                    50.41  251.2
#     area (worst):                         185.2  4254.0
#     smoothness (worst):                   0.071  0.223
#     compactness (worst):                  0.027  1.058
#     concavity (worst):                    0.0    1.252
#     concave points (worst):               0.0    0.291
#     symmetry (worst):                     0.156  0.664
#     fractal dimension (worst):            0.055  0.208
#     ===================================== ====== ======
#
#     :Missing Attribute Values: None
#
#     :Class Distribution: 212 - Malignant, 357 - Benign
#
#     :Creator:  Dr. William H. Wolberg, W. Nick Street, Olvi L. Mangasarian
#
#     :Donor: Nick Street
#
#     :Date: November, 1995
#
# This is a copy of UCI ML Breast Cancer Wisconsin (Diagnostic) datasets.
# https://goo.gl/U2Uwz2
#
# Features are computed from a digitized image of a fine needle
# aspirate (FNA) of a breast mass.  They describe
# characteristics of the cell nuclei present in the image.
#
# Separating plane described above was obtained using
# Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree
# Construction Via Linear Programming." Proceedings of the 4th
# Midwest Artificial Intelligence and Cognitive Science Society,
# pp. 97-101, 1992], a classification method which uses linear
# programming to construct a decision tree.  Relevant features
# were selected using an exhaustive search in the space of 1-4
# features and 1-3 separating planes.
#
# The actual linear program used to obtain the separating plane
# in the 3-dimensional space is that described in:
# [K. P. Bennett and O. L. Mangasarian: "Robust Linear
# Programming Discrimination of Two Linearly Inseparable Sets",
# Optimization Methods and Software 1, 1992, 23-34].
#
# This database is also available through the UW CS ftp server:
#
# ftp ftp.cs.wisc.edu
# cd math-prog/cpo-dataset/machine-learn/WDBC/
#
# .. topic:: References
#
#    - W.N. Street, W.H. Wolberg and O.L. Mangasarian. Nuclear feature extraction
#      for breast tumor diagnosis. IS&T/SPIE 1993 International Symposium on
#      Electronic Imaging: Science and Technology, volume 1905, pages 861-870,
#      San Jose, CA, 1993.
#    - O.L. Mangasarian, W.N. Street and W.H. Wolberg. Breast cancer diagnosis and
#      prognosis via linear programming. Operations Research, 43(4), pages 570-577,
#      July-August 1995.
#    - W.H. Wolberg, W.N. Street, and O.L. Mangasarian. Machine learning techniques
#      to diagnose breast cancer from fine-needle aspirates. Cancer Letters 77 (1994)
#      163-171.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/cancer_classification.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
#  13  area error               569 non-null    float64
#  14  smoothness error         569 non-null    float64
#  15  compactness error        569 non-null    float64
#  16  concavity error          569 non-null    float64
#  17  concave points error     569 non-null    float64
#  18  symmetry error           569 non-null    float64
#  19  fractal dimension error  569 non-null    float64
#  20  worst radius             569 non-null    float64
#  21  worst texture            569 non-null    float64
#  22  worst perimeter          569 non-null    float64
#  23  worst area               569 non-null    float64
#  24  worst smoothness         569 non-null    float64
#  25  worst compactness        569 non-null    float64
#  26  worst concavity          569 non-null    float64
#  27  worst concave points     569 non-null    float64
#  28  worst symmetry           569 non-null    float64
#  29  worst fractal dimension  569 non-null    float64
#  30  benign_0__mal_1          569 non-null    int64
# dtypes: float64(30), int64(1)
# memory usage: 137.9 KB

# %%
df.describe().transpose()
# Out:
#                          count        mean         std         min  \
# mean radius              569.0   14.127292    3.524049    6.981000
# mean texture             569.0   19.289649    4.301036    9.710000
# mean perimeter           569.0   91.969033   24.298981   43.790000
# mean area                569.0  654.889104  351.914129  143.500000
# mean smoothness          569.0    0.096360    0.014064    0.052630
# mean compactness         569.0    0.104341    0.052813    0.019380
# mean concavity           569.0    0.088799    0.079720    0.000000
# mean concave points      569.0    0.048919    0.038803    0.000000
# mean symmetry            569.0    0.181162    0.027414    0.106000
# mean fractal dimension   569.0    0.062798    0.007060    0.049960
# radius error             569.0    0.405172    0.277313    0.111500
# texture error            569.0    1.216853    0.551648    0.360200
# perimeter error          569.0    2.866059    2.021855    0.757000
# area error               569.0   40.337079   45.491006    6.802000
# smoothness error         569.0    0.007041    0.003003    0.001713
# compactness error        569.0    0.025478    0.017908    0.002252
# concavity error          569.0    0.031894    0.030186    0.000000
# concave points error     569.0    0.011796    0.006170    0.000000
# symmetry error           569.0    0.020542    0.008266    0.007882
# fractal dimension error  569.0    0.003795    0.002646    0.000895
# worst radius             569.0   16.269190    4.833242    7.930000
# worst texture            569.0   25.677223    6.146258   12.020000
# worst perimeter          569.0  107.261213   33.602542   50.410000
# worst area               569.0  880.583128  569.356993  185.200000
# worst smoothness         569.0    0.132369    0.022832    0.071170
# worst compactness        569.0    0.254265    0.157336    0.027290
# worst concavity          569.0    0.272188    0.208624    0.000000
# worst concave points     569.0    0.114606    0.065732    0.000000
# worst symmetry           569.0    0.290076    0.061867    0.156500
# worst fractal dimension  569.0    0.083946    0.018061    0.055040
# benign_0__mal_1          569.0    0.627417    0.483918    0.000000
#
#                                 25%         50%          75%         max
# mean radius               11.700000   13.370000    15.780000    28.11000
# mean texture              16.170000   18.840000    21.800000    39.28000
# mean perimeter            75.170000   86.240000   104.100000   188.50000
# mean area                420.300000  551.100000   782.700000  2501.00000
# mean smoothness            0.086370    0.095870     0.105300     0.16340
# mean compactness           0.064920    0.092630     0.130400     0.34540
# mean concavity             0.029560    0.061540     0.130700     0.42680
# mean concave points        0.020310    0.033500     0.074000     0.20120
# mean symmetry              0.161900    0.179200     0.195700     0.30400
# mean fractal dimension     0.057700    0.061540     0.066120     0.09744
# radius error               0.232400    0.324200     0.478900     2.87300
# texture error              0.833900    1.108000     1.474000     4.88500
# perimeter error            1.606000    2.287000     3.357000    21.98000
# area error                17.850000   24.530000    45.190000   542.20000
# smoothness error           0.005169    0.006380     0.008146     0.03113
# compactness error          0.013080    0.020450     0.032450     0.13540
# concavity error            0.015090    0.025890     0.042050     0.39600
# concave points error       0.007638    0.010930     0.014710     0.05279
# symmetry error             0.015160    0.018730     0.023480     0.07895
# fractal dimension error    0.002248    0.003187     0.004558     0.02984
# worst radius              13.010000   14.970000    18.790000    36.04000
# worst texture             21.080000   25.410000    29.720000    49.54000
# worst perimeter           84.110000   97.660000   125.400000   251.20000
# worst area               515.300000  686.500000  1084.000000  4254.00000
# worst smoothness           0.116600    0.131300     0.146000     0.22260
# worst compactness          0.147200    0.211900     0.339100     1.05800
# worst concavity            0.114500    0.226700     0.382900     1.25200
# worst concave points       0.064930    0.099930     0.161400     0.29100
# worst symmetry             0.250400    0.282200     0.317900     0.66380
# worst fractal dimension    0.071460    0.080040     0.092080     0.20750
# benign_0__mal_1            0.000000    1.000000     1.000000     1.00000

# %%
sns.countplot(x="benign_0__mal_1",data=df)
# Out:
# <AxesSubplot:xlabel='benign_0__mal_1', ylabel='count'>

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.corr()["benign_0__mal_1"].sort_values().drop("benign_0__mal_1").plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X=df.drop("benign_0__mal_1",axis=1).values
y=df["benign_0__mal_1"].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25,random_state=101)

# %% [markdown]
# ## Scaling Data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Creating the Model
#
#     # For a binary classification problem
#     model.compile(optimizer='rmsprop',
#                   loss='binary_crossentropy',
#                   metrics=['accuracy'])

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout

# %%
X_train.shape
# Out:
# (426, 30)

# %%
model = Sequential()

# https://stats.stackexchange.com/questions/181/how-to-choose-the-number-of-hidden-layers-and-nodes-in-a-feedforward-neural-netw

model.add(Dense(units=30,activation="relu"))
model.add(Dense(units=15,activation="relu"))
model.add(Dense(units=1,activation="sigmoid"))

# For a binary classification problem
model.compile(loss="binary_crossentropy", optimizer="adam")

# %% [markdown]
# ## Training the Model
#
# ### Example One: Choosing too many epochs and overfitting!

# %%
# https://stats.stackexchange.com/questions/164876/tradeoff-batch-size-vs-number-of-iterations-to-train-a-neural-network
# https://datascience.stackexchange.com/questions/18414/are-there-any-rules-for-choosing-the-size-of-a-mini-batch

model.fit(x=X_train, 
          y=y_train, 
          epochs=100,#600,
          validation_data=(X_test, y_test), verbose=1
          )
# Out:
# Epoch 1/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6580 - val_loss: 0.6434
# Epoch 2/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6201 - val_loss: 0.6030
# Epoch 3/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5826 - val_loss: 0.5600
# Epoch 4/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.5369 - val_loss: 0.5114
# Epoch 5/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4918 - val_loss: 0.4617
# Epoch 6/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4438 - val_loss: 0.4096
# Epoch 7/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3966 - val_loss: 0.3586
# Epoch 8/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3526 - val_loss: 0.3135
# Epoch 9/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3129 - val_loss: 0.2758
# Epoch 10/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2804 - val_loss: 0.2424
# Epoch 11/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2565 - val_loss: 0.2202
# Epoch 12/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2360 - val_loss: 0.2051
# Epoch 13/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2218 - val_loss: 0.1858
# Epoch 14/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2059 - val_loss: 0.1765
# Epoch 15/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2002 - val_loss: 0.1649
# Epoch 16/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1832 - val_loss: 0.1574
# Epoch 17/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1742 - val_loss: 0.1493
# Epoch 18/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1665 - val_loss: 0.1498
# Epoch 19/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1571 - val_loss: 0.1379
# Epoch 20/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1500 - val_loss: 0.1372
# Epoch 21/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1436 - val_loss: 0.1302
# Epoch 22/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1377 - val_loss: 0.1277
# Epoch 23/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1322 - val_loss: 0.1227
# Epoch 24/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1268 - val_loss: 0.1217
# Epoch 25/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1201 - val_loss: 0.1212
# Epoch 26/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1173 - val_loss: 0.1164
# Epoch 27/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1127 - val_loss: 0.1164
# Epoch 28/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1077 - val_loss: 0.1138
# Epoch 29/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1023 - val_loss: 0.1101
# Epoch 30/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0989 - val_loss: 0.1082
# Epoch 31/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0959 - val_loss: 0.1093
# Epoch 32/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0927 - val_loss: 0.1071
# Epoch 33/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0903 - val_loss: 0.1062
# Epoch 34/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0884 - val_loss: 0.1058
# Epoch 35/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0838 - val_loss: 0.1086
# Epoch 36/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0822 - val_loss: 0.1053
# Epoch 37/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0807 - val_loss: 0.1067
# Epoch 38/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0856 - val_loss: 0.1057
# Epoch 39/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0810 - val_loss: 0.1059
# Epoch 40/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0746 - val_loss: 0.1037
# Epoch 41/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0735 - val_loss: 0.1086
# Epoch 42/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0716 - val_loss: 0.1043
# Epoch 43/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0705 - val_loss: 0.1070
# Epoch 44/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0697 - val_loss: 0.1067
# Epoch 45/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0685 - val_loss: 0.1045
# Epoch 46/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0671 - val_loss: 0.1046
# Epoch 47/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0660 - val_loss: 0.1073
# Epoch 48/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0649 - val_loss: 0.1059
# Epoch 49/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0645 - val_loss: 0.1061
# Epoch 50/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0635 - val_loss: 0.1060
# Epoch 51/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0619 - val_loss: 0.1111
# Epoch 52/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0639 - val_loss: 0.1084
# Epoch 53/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0608 - val_loss: 0.1101
# Epoch 54/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0600 - val_loss: 0.1097
# Epoch 55/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0627 - val_loss: 0.1104
# Epoch 56/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0607 - val_loss: 0.1121
# Epoch 57/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0585 - val_loss: 0.1079
# Epoch 58/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0570 - val_loss: 0.1096
# Epoch 59/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0582 - val_loss: 0.1123
# Epoch 60/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0567 - val_loss: 0.1110
# Epoch 61/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0571 - val_loss: 0.1094
# Epoch 62/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0556 - val_loss: 0.1109
# Epoch 63/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0547 - val_loss: 0.1122
# Epoch 64/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0547 - val_loss: 0.1119
# Epoch 65/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0544 - val_loss: 0.1091
# Epoch 66/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0560 - val_loss: 0.1130
# Epoch 67/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0545 - val_loss: 0.1111
# Epoch 68/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0569 - val_loss: 0.1138
# Epoch 69/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0534 - val_loss: 0.1110
# Epoch 70/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0533 - val_loss: 0.1133
# Epoch 71/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0509 - val_loss: 0.1193
# Epoch 72/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0525 - val_loss: 0.1123
# Epoch 73/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0529 - val_loss: 0.1139
# Epoch 74/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0501 - val_loss: 0.1204
# Epoch 75/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0593 - val_loss: 0.1120
# Epoch 76/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0571 - val_loss: 0.1163
# Epoch 77/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0520 - val_loss: 0.1149
# Epoch 78/100
# 14/14 [==============================] - ETA: 0s - loss: 0.029 - 0s 2ms/step - loss: 0.0499 - val_loss: 0.1172
# Epoch 79/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0491 - val_loss: 0.1168
# Epoch 80/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0495 - val_loss: 0.1150
# Epoch 81/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0501 - val_loss: 0.1200
# Epoch 82/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0488 - val_loss: 0.1162
# Epoch 83/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0510 - val_loss: 0.1183
# Epoch 84/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0476 - val_loss: 0.1204
# Epoch 85/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0476 - val_loss: 0.1189
# Epoch 86/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0494 - val_loss: 0.1178
# Epoch 87/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0482 - val_loss: 0.1190
# Epoch 88/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0479 - val_loss: 0.1167
# Epoch 89/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0495 - val_loss: 0.1205
# Epoch 90/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0476 - val_loss: 0.1287
# Epoch 91/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0494 - val_loss: 0.1230
# Epoch 92/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0467 - val_loss: 0.1199
# Epoch 93/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0458 - val_loss: 0.1244
# Epoch 94/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0454 - val_loss: 0.1239
# Epoch 95/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0462 - val_loss: 0.1227
# Epoch 96/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0525 - val_loss: 0.1266
# Epoch 97/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0486 - val_loss: 0.1238
# Epoch 98/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0495 - val_loss: 0.1294
# Epoch 99/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0439 - val_loss: 0.1224
# Epoch 100/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0438 - val_loss: 0.1252

# %%
model_loss = pd.DataFrame(model.history.history)

# %%
model_loss.head()
# Out:
#        loss  val_loss
# 0  0.658004  0.643377
# 1  0.620052  0.603047
# 2  0.582579  0.560005
# 3  0.536927  0.511381
# 4  0.491826  0.461700

# %%
model_loss.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Example Two: Early Stopping
#
# We obviously trained too much! Let's use early stopping to track the val_loss and stop training once it begins increasing too much!

# %%
model = Sequential()
model.add(Dense(units=30,activation="relu"))
model.add(Dense(units=15,activation="relu"))
model.add(Dense(units=1,activation="sigmoid"))
model.compile(loss="binary_crossentropy", optimizer="adam")

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %% [markdown]
# Stop training when a monitored quantity has stopped improving.
#
#     Arguments:
#         monitor: Quantity to be monitored.
#         min_delta: Minimum change in the monitored quantity
#             to qualify as an improvement, i.e. an absolute
#             change of less than min_delta, will count as no
#             improvement.
#         patience: Number of epochs with no improvement
#             after which training will be stopped.
#         verbose: verbosity mode.
#         mode: One of `{"auto", "min", "max"}`. In `min` mode,
#             training will stop when the quantity
#             monitored has stopped decreasing; in `max`
#             mode it will stop when the quantity
#             monitored has stopped increasing; in `auto`
#             mode, the direction is automatically inferred
#             from the name of the monitored quantity.

# %%
early_stop = EarlyStopping(monitor="val_loss", mode="min", verbose=1, patience=25)

# %%
model.fit(x=X_train, 
          y=y_train, 
          epochs=100,#600,
          validation_data=(X_test, y_test), verbose=1,
          callbacks=[early_stop]
          )
# Out:
# Epoch 1/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6785 - val_loss: 0.6664
# Epoch 2/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6499 - val_loss: 0.6370
# Epoch 3/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6163 - val_loss: 0.6005
# Epoch 4/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5760 - val_loss: 0.5555
# Epoch 5/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5280 - val_loss: 0.5038
# Epoch 6/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4752 - val_loss: 0.4489
# Epoch 7/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4227 - val_loss: 0.3970
# Epoch 8/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3840 - val_loss: 0.3544
# Epoch 9/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3471 - val_loss: 0.3216
# Epoch 10/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3098 - val_loss: 0.2873
# Epoch 11/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2845 - val_loss: 0.2621
# Epoch 12/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2621 - val_loss: 0.2434
# Epoch 13/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2432 - val_loss: 0.2206
# Epoch 14/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2269 - val_loss: 0.2059
# Epoch 15/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2122 - val_loss: 0.1940
# Epoch 16/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1996 - val_loss: 0.1813
# Epoch 17/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1885 - val_loss: 0.1712
# Epoch 18/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1812 - val_loss: 0.1647
# Epoch 19/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1701 - val_loss: 0.1568
# Epoch 20/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1634 - val_loss: 0.1494
# Epoch 21/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1633 - val_loss: 0.1456
# Epoch 22/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1456 - val_loss: 0.1374
# Epoch 23/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1396 - val_loss: 0.1354
# Epoch 24/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1327 - val_loss: 0.1298
# Epoch 25/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1272 - val_loss: 0.1259
# Epoch 26/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1221 - val_loss: 0.1224
# Epoch 27/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1165 - val_loss: 0.1216
# Epoch 28/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1157 - val_loss: 0.1172
# Epoch 29/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1089 - val_loss: 0.1164
# Epoch 30/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1046 - val_loss: 0.1146
# Epoch 31/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1009 - val_loss: 0.1141
# Epoch 32/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0974 - val_loss: 0.1117
# Epoch 33/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0950 - val_loss: 0.1134
# Epoch 34/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0940 - val_loss: 0.1103
# Epoch 35/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0906 - val_loss: 0.1086
# Epoch 36/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0871 - val_loss: 0.1066
# Epoch 37/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0848 - val_loss: 0.1080
# Epoch 38/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0834 - val_loss: 0.1081
# Epoch 39/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0801 - val_loss: 0.1053
# Epoch 40/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0812 - val_loss: 0.1093
# Epoch 41/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0771 - val_loss: 0.1034
# Epoch 42/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0796 - val_loss: 0.1042
# Epoch 43/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0761 - val_loss: 0.1052
# Epoch 44/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0733 - val_loss: 0.1040
# Epoch 45/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0721 - val_loss: 0.1082
# Epoch 46/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0721 - val_loss: 0.1042
# Epoch 47/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0724 - val_loss: 0.1024
# Epoch 48/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0703 - val_loss: 0.1054
# Epoch 49/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0692 - val_loss: 0.1028
# Epoch 50/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0682 - val_loss: 0.1064
# Epoch 51/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0740 - val_loss: 0.1074
# Epoch 52/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0678 - val_loss: 0.1025
# Epoch 53/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0651 - val_loss: 0.1056
# Epoch 54/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.0661 - val_loss: 0.1013
# Epoch 55/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0644 - val_loss: 0.1068
# Epoch 56/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0655 - val_loss: 0.1025
# Epoch 57/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0641 - val_loss: 0.1049
# Epoch 58/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0621 - val_loss: 0.1034
# Epoch 59/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0617 - val_loss: 0.1037
# Epoch 60/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0692 - val_loss: 0.1024
# Epoch 61/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0649 - val_loss: 0.1062
# Epoch 62/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0602 - val_loss: 0.1041
# Epoch 63/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0590 - val_loss: 0.1044
# Epoch 64/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0593 - val_loss: 0.1083
# Epoch 65/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0584 - val_loss: 0.1038
# Epoch 66/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0608 - val_loss: 0.1081
# Epoch 67/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.0597 - val_loss: 0.1028
# Epoch 68/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0579 - val_loss: 0.1055
# Epoch 69/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0610 - val_loss: 0.1042
# Epoch 70/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0574 - val_loss: 0.1062
# Epoch 71/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0564 - val_loss: 0.1077
# Epoch 72/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0585 - val_loss: 0.1065
# Epoch 73/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0566 - val_loss: 0.1073
# Epoch 74/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0624 - val_loss: 0.1065
# Epoch 75/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0593 - val_loss: 0.1041
# Epoch 76/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0577 - val_loss: 0.1056
# Epoch 77/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0555 - val_loss: 0.1061
# Epoch 78/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0551 - val_loss: 0.1087
# Epoch 79/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0539 - val_loss: 0.1076
# Epoch 00079: early stopping

# %%
model_loss = pd.DataFrame(model.history.history)
model_loss.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Example Three: Adding in DropOut Layers

# %%
from tensorflow.keras.layers import Dropout

# %%
model = Sequential()
model.add(Dense(units=30,activation="relu"))
model.add(Dropout(0.5))

model.add(Dense(units=15,activation="relu"))
model.add(Dropout(0.5))

model.add(Dense(units=1,activation="sigmoid"))
model.compile(loss="binary_crossentropy", optimizer="adam")

# %%
model.fit(x=X_train, 
          y=y_train, 
          epochs=100,#600,
          validation_data=(X_test, y_test), verbose=1,
          callbacks=[early_stop]
          )
# Out:
# Epoch 1/100
# 14/14 [==============================] - 0s 8ms/step - loss: 0.6957 - val_loss: 0.6759
# Epoch 2/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6827 - val_loss: 0.6656
# Epoch 3/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6684 - val_loss: 0.6536
# Epoch 4/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6649 - val_loss: 0.6399
# Epoch 5/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6496 - val_loss: 0.6275
# Epoch 6/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6325 - val_loss: 0.6079
# Epoch 7/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6190 - val_loss: 0.5806
# Epoch 8/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5906 - val_loss: 0.5542
# Epoch 9/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5672 - val_loss: 0.5238
# Epoch 10/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5439 - val_loss: 0.4968
# Epoch 11/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5052 - val_loss: 0.4607
# Epoch 12/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5068 - val_loss: 0.4329
# Epoch 13/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4910 - val_loss: 0.4163
# Epoch 14/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4575 - val_loss: 0.3956
# Epoch 15/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4557 - val_loss: 0.3771
# Epoch 16/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4298 - val_loss: 0.3547
# Epoch 17/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4151 - val_loss: 0.3326
# Epoch 18/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3954 - val_loss: 0.3127
# Epoch 19/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.3839 - val_loss: 0.2936
# Epoch 20/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3952 - val_loss: 0.2872
# Epoch 21/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.3507 - val_loss: 0.2666
# Epoch 22/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3556 - val_loss: 0.2519
# Epoch 23/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3450 - val_loss: 0.2451
# Epoch 24/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3370 - val_loss: 0.2525
# Epoch 25/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3251 - val_loss: 0.2272
# Epoch 26/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2976 - val_loss: 0.2091
# Epoch 27/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2946 - val_loss: 0.1976
# Epoch 28/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2958 - val_loss: 0.1928
# Epoch 29/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.2896 - val_loss: 0.1926
# Epoch 30/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2774 - val_loss: 0.1824
# Epoch 31/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2821 - val_loss: 0.1769
# Epoch 32/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2474 - val_loss: 0.1815
# Epoch 33/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2616 - val_loss: 0.1675
# Epoch 34/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2391 - val_loss: 0.1558
# Epoch 35/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2332 - val_loss: 0.1601
# Epoch 36/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2442 - val_loss: 0.1551
# Epoch 37/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.2246 - val_loss: 0.1495
# Epoch 38/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2253 - val_loss: 0.1430
# Epoch 39/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2165 - val_loss: 0.1371
# Epoch 40/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2306 - val_loss: 0.1359
# Epoch 41/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2415 - val_loss: 0.1321
# Epoch 42/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2153 - val_loss: 0.1415
# Epoch 43/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2089 - val_loss: 0.1378
# Epoch 44/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1794 - val_loss: 0.1277
# Epoch 45/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1938 - val_loss: 0.1187
# Epoch 46/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1844 - val_loss: 0.1254
# Epoch 47/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1851 - val_loss: 0.1177
# Epoch 48/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1791 - val_loss: 0.1164
# Epoch 49/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1858 - val_loss: 0.1095
# Epoch 50/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1686 - val_loss: 0.1174
# Epoch 51/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1530 - val_loss: 0.1209
# Epoch 52/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1701 - val_loss: 0.1104
# Epoch 53/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1780 - val_loss: 0.1114
# Epoch 54/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1613 - val_loss: 0.1062
# Epoch 55/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1566 - val_loss: 0.1170
# Epoch 56/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1751 - val_loss: 0.1011
# Epoch 57/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1524 - val_loss: 0.0991
# Epoch 58/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1586 - val_loss: 0.1030
# Epoch 59/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1419 - val_loss: 0.0972
# Epoch 60/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1632 - val_loss: 0.0972
# Epoch 61/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1452 - val_loss: 0.0936
# Epoch 62/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1774 - val_loss: 0.1018
# Epoch 63/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1624 - val_loss: 0.1002
# Epoch 64/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1663 - val_loss: 0.1045
# Epoch 65/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1432 - val_loss: 0.0903
# Epoch 66/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1659 - val_loss: 0.0938
# Epoch 67/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1324 - val_loss: 0.0971
# Epoch 68/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1336 - val_loss: 0.0929
# Epoch 69/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1258 - val_loss: 0.0904
# Epoch 70/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1198 - val_loss: 0.0897
# Epoch 71/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1147 - val_loss: 0.0939
# Epoch 72/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1531 - val_loss: 0.0951
# Epoch 73/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1321 - val_loss: 0.0934
# Epoch 74/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1210 - val_loss: 0.0967
# Epoch 75/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1489 - val_loss: 0.0964
# Epoch 76/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1286 - val_loss: 0.0912
# Epoch 77/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1098 - val_loss: 0.0838
# Epoch 78/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1273 - val_loss: 0.0878
# Epoch 79/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1464 - val_loss: 0.0881
# Epoch 80/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1126 - val_loss: 0.1013
# Epoch 81/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1066 - val_loss: 0.0862
# Epoch 82/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1271 - val_loss: 0.0886
# Epoch 83/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1308 - val_loss: 0.1090
# Epoch 84/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1261 - val_loss: 0.0985
# Epoch 85/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1271 - val_loss: 0.0860
# Epoch 86/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1238 - val_loss: 0.1003
# Epoch 87/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0940 - val_loss: 0.0813
# Epoch 88/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1411 - val_loss: 0.0885
# Epoch 89/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1094 - val_loss: 0.0790
# Epoch 90/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1233 - val_loss: 0.0801
# Epoch 91/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1124 - val_loss: 0.0866
# Epoch 92/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1094 - val_loss: 0.0812
# Epoch 93/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1088 - val_loss: 0.0845
# Epoch 94/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.1168 - val_loss: 0.0783
# Epoch 95/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1197 - val_loss: 0.0844
# Epoch 96/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0993 - val_loss: 0.0844
# Epoch 97/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1038 - val_loss: 0.0757
# Epoch 98/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1060 - val_loss: 0.0783
# Epoch 99/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1142 - val_loss: 0.0832
# Epoch 100/100
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0930 - val_loss: 0.0837

# %%
model_loss = pd.DataFrame(model.history.history)
model_loss.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Model Evaluation

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
predictions = model.predict(X_test)
predictions_classes = [1 if i > 0.5 else 0 for i in predictions]

# %%
# https://en.wikipedia.org/wiki/Precision_and_recall
print(classification_report(y_test,predictions_classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.98      0.96        55
#            1       0.99      0.95      0.97        88
#
#     accuracy                           0.97       143
#    macro avg       0.96      0.97      0.96       143
# weighted avg       0.97      0.97      0.97       143

# %%
confusion_matrix(y_test,predictions_classes)
# Out:
# array([[54,  1],
#        [ 4, 84]])
